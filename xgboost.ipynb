# %%
dataset = 'archive (1)\dataset\audio\speakers'

# %%
import librosa
import numpy as np

SAMPLE_RATE = 16000
DURATION = 2
SAMPLES = SAMPLE_RATE * DURATION
N_MFCC = 40

def preprocess_audio(file_path):
    audio, sr = librosa.load(file_path, sr=SAMPLE_RATE, mono=True)
    audio, _ = librosa.effects.trim(audio)

    if len(audio) < SAMPLES:
        audio = np.pad(audio, (0, SAMPLES - len(audio)))
    else:
        audio = audio[:SAMPLES]

    return audio, sr

# %%
file_path = r"E:\voice_windows_ai\archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\1d9f3920-4474-11e9-a9a5-5dbec3b8816a.wav"

audio, sr = preprocess_audio(file_path)

print(audio.shape)
print(sr)
# Out:
# (32000,)
# 16000

# %%
import IPython.display as ipd
ipd.Audio(audio, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_features(audio, sr):
    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sr,
        n_mfcc=N_MFCC
    )

    # statistical pooling (speaker independent)
    mfcc_mean = np.mean(mfcc, axis=1)
    mfcc_std = np.std(mfcc, axis=1)

    return np.concatenate([mfcc_mean, mfcc_std])  # shape: (80,)

# %%
import os

DATASET_PATH = r"archive (1)\dataset\audio\speakers"

def build_unlabeled_dataset(dataset_path):
    X = []
    meta = []

    for speaker_id in os.listdir(dataset_path):
        speaker_path = os.path.join(dataset_path, speaker_id)

        if not os.path.isdir(speaker_path):
            continue

        for file in os.listdir(speaker_path):
            if not file.endswith(".wav"):
                continue

            file_path = os.path.join(speaker_path, file)

            try:
                audio, sr = preprocess_audio(file_path)
                features = extract_features(audio, sr)

                X.append(features)
                meta.append({
                    "speaker_id": speaker_id,
                    "file": file,
                    "path": file_path
                })

            except Exception as e:
                print("Error:", file_path, e)

    return np.array(X), meta

# %%
X, meta = build_unlabeled_dataset(DATASET_PATH)

print("Feature matrix shape:", X.shape)
print("First sample metadata:", meta[0])
# Out:
# Feature matrix shape: (11309, 80)
# First sample metadata: {'speaker_id': '2BqVo8kVB2Skwgyb', 'file': '03592c80-447c-11e9-a9a5-5dbec3b8816a.wav', 'path': 'archive (1)\\dataset\\audio\\speakers\\2BqVo8kVB2Skwgyb\\03592c80-447c-11e9-a9a5-5dbec3b8816a.wav'}

# %%
print('Nans', np.isnan(X).sum())
print('Infs', np.isinf(X).sum())
# Out:
# Nans 0
# Infs 0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
NUM_COMMANDS = 6

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(
    n_clusters=NUM_COMMANDS,
    random_state=42,
    n_init=10
)

cluster_ids = kmeans.fit_predict(X_scaled)

# %%
for cid in range(NUM_COMMANDS):
    print(f"\n🔹 Cluster {cid}")
    samples = [meta[i]["path"] for i in range(len(meta)) if cluster_ids[i] == cid][:5]
    for s in samples:
        print(" ", s)
# Out:
# 🔹 Cluster 0
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\03592c80-447c-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\120de470-447a-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\1d9f3920-4474-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\230c5690-447e-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\256b2060-4479-11e9-a9a5-5dbec3b8816a.wav
#
# 🔹 Cluster 1
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\34e73840-447d-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\78895af0-4479-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\7ee96810-447c-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\9e5f9b10-447c-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\ce762960-447a-11e9-a9a5-5dbec3b8816a.wav
#
# 🔹 Cluster 2
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\014e42a0-457f-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\03896590-457f-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\145ea900-457c-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\173ce9c0-457c-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\326be0b0-457d-11e9-9600-8f19ade2128c.wav
#
# 🔹 Cluster 3
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\744ff850-457c-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\764a1aa0-457c-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\836662d0-457b-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\88f78730-457e-11e9-9600-8f19ade2128c.wav
#   archive (1)\dataset\audio\speakers\5BEzPgPKe8taG9OB\8b2c4180-457e-11e9-9600-8f19ade2128c.wav
#
# 🔹 Cluster 4
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\07858300-447a-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\5d9bdd00-447c-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\c4808020-447c-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2ojo7YRL7Gck83Z3\06931a20-45e2-11e9-81ce-69b74fd7e64e.wav
#   archive (1)\dataset\audio\speakers\2ojo7YRL7Gck83Z3\2917e220-45e1-11e9-81ce-69b74fd7e64e.wav
#
# 🔹 Cluster 5
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\09bd4a90-447a-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\0a3129c0-4474-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\0ee42a80-4474-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\472150f0-447c-11e9-a9a5-5dbec3b8816a.wav
#   archive (1)\dataset\audio\speakers\2BqVo8kVB2Skwgyb\4f9e4770-447b-11e9-a9a5-5dbec3b8816a.wav

# %%
cluster_to_command = {
    0: "open_browser",
    1: "close_browser",
    2: "volume_up",
    3: "volume_down",
    4: "play_music",
    5: "stop_music"
}

# %%
y = np.array([cluster_to_command[c] for c in cluster_ids])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

print("Classes:", label_encoder.classes_)
# Out:
# Classes: ['close_browser' 'open_browser' 'play_music' 'stop_music' 'volume_down'
#  'volume_up']

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="multi:softprob",
    eval_metric="mlogloss",
    random_state=42
)

model.fit(X_train, y_train)

print("Train accuracy:", model.score(X_train, y_train))
print("Test accuracy:", model.score(X_test, y_test))
# Out:
# Train accuracy: 1.0
# Test accuracy: 0.9363395225464191

# %%
with open("voice_command_xgb.pkl", "rb") as f:
    data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 with open("voice_command_xgb.pkl", "rb") as f:
#       2     data = pickle.load(f)
#
# File c:\Users\ns062\anaconda3\envs\winai\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'voice_command_xgb.pkl'
